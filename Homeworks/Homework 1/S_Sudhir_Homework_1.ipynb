# %% [markdown]
# ***
# # Homework 1
#
# **Course:** MATH 616 - Data-Driven Dynamical Systems, Stochastic Modeling and Prediction
#
# **Name:** Shrivats Sudhir
#
# **NetID:** ssudhir2
#
# **Email:** ssudhir2@wisc.edu
#
# **Date:** September 9th, 2024
# ***

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Question 1.
#
# **Consider the linear damped-forced model:**
# $$ \frac{du}{dt} = -au + f $$
# **where $a > 0$ and $f$ are both constants.**

# %% [markdown]
# ### (a.)
#
# **Derive the analytic solution of $u$ with initial condition being $u(t=0) = u_0$.**

# %% [markdown]
# \begin{equation*}
#     \begin{split}
#         \frac{du}{dt}     &= -au + f\\
#         dt                &= \frac{1}{-au + f} \; du\\
#         \int dt           &= \int \frac{1}{-au + f} \; du\\
#         t + C_1           &= -\frac{1}{a} \cdot \text{log}(-au + f) + C_2\\
#         u(t)              &= \underbrace{-\frac{1}{a \cdot \text{exp}(a(C_1-C_2))}}_{=C} \cdot \text{exp}(-at) + \frac{f}{a}\\
#     \end{split}
# \end{equation*}
#
# The analytical solution of $u$ is:
# $$ u(t) = C \cdot \text{exp}(-at) + \frac{f}{a} $$
#
# Furthermore, we can see that at $t=0$:
# \begin{equation*}
#     \begin{split}
#     u_0 &= C + \frac{f}{a}\\
#     C   &= u_0 - \frac{f}{a}
#     \end{split}
# \end{equation*}
#
# Therefore, we have that:
# \begin{equation*}
#     \begin{split}
#     u(t) &= \bigg(u_0 - \frac{f}{a}\bigg) \cdot \text{exp}(-at) + \frac{f}{a}\\
#          &= u_0 \cdot \text{exp}(-at) + \frac{f}{a}\big(1 - \text{exp}(-at)\big)
#     \end{split}
# \end{equation*}
#
# which is the analytical solution of $u$, where $a>0$ and $f$ are both constants.

# %%
def du_dt(a, f, u):
    
    """
    ODE function u' = (-au + f).
    
    --- inputs ---
    - a: constant
    - f: constant
    - u: variable
    """
    
    return (-a*u) + f

def u(u0, a, f, t):
    
    """
    Analytical solution u of u'.
    
    --- inputs ---
    - u0: initial condition
    - a: constant
    - f: constant
    - t: variable
    """
    
    return u0 * np.exp(-a*t) + f/a * (1 - np.exp(-a*t))

def forward_euler(u0, t0, tend, h, a, f):
    
    """
    Implementing forward euler to estimate numerical solution of u'.

    --- inputs ---
    - u0: initial condition
    - t0: initial time
    - tend: final time
    - h: time-step
    - a: constant (for function du_dt)
    - f: constant (for function du_dt)
    """
    
    num_steps = int((tend-t0)/h)
    t = np.linspace(t0, tend, num_steps+1)
    y = np.zeros(num_steps+1)
    y[0] = u0
    
    for i in range(num_steps):
        y[i+1] = y[i] + h * du_dt(a=a, f=f, u=y[i])
    
    return t, y

# %% [markdown]
# ### (b.)
#
# **Use the forward Euler method to numerically solve the equation. Here, use the initial condition $u_0=5$. The parameters are $a=0.5$ and $f=2$. Run the model starting from $t=0$ and ending at $t=2$.**

# %% [markdown]
# We know that the first-order ODE:
# $$ u' = \frac{du}{dt} = -au + t $$
#
# Which for a small enough $h$ can be approximated as:
# \begin{equation*}
#     \begin{split}
#         u' &\approx \frac{u(t+h) - u(t)}{h}\\
#         u(t+h) &\approx u' \cdot h + u(t)\\
#     \end{split}
# \end{equation*}
#
# We can code the above (with $h=0.1$) and print an output table which shows the following columns:
# * `t`: time (defined by time_step parameter $h$)
# * `true_soln`: analytical solution when plugging in $t$ in $u(t)$
# * `approx_soln`: forward euler approximation for $u(t)$ at time $t$
# * `abs_diff`: absolute difference between true_soln and approx_soln

# %%
u0 = 5
a = 0.5
f = 2
t0 = 0
tend = 2
h = 0.1

t, approx_y = forward_euler(u0=5, t0=0, tend=2, h=h, a=a, f=f)

true_y = np.zeros(len(t))
for i in range(len(t)):
    true_y[i] = u(u0=u0, a=a, f=f, t=t[i])
    
df = pd.DataFrame({'t': np.linspace(0, 2, len(true_y)), 
                   'true_soln': true_y, 
                   'approx_soln': approx_y, 
                   'abs_diff': np.abs(true_y - approx_y)})
df.style.background_gradient(cmap='viridis', subset=['true_soln', 'approx_soln', 'abs_diff'])
# Out:
# <style type="text/css">
# #T_ccb1d_row0_col1, #T_ccb1d_row0_col2, #T_ccb1d_row19_col3, #T_ccb1d_row20_col3 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_ccb1d_row0_col3, #T_ccb1d_row20_col1, #T_ccb1d_row20_col2 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_ccb1d_row1_col1, #T_ccb1d_row1_col2 {
#   background-color: #cde11d;
#   color: #000000;
# }
# #T_ccb1d_row1_col3 {
#   background-color: #472e7c;
#   color: #f1f1f1;
# }
# #T_ccb1d_row2_col1, #T_ccb1d_row2_col2 {
#   background-color: #9bd93c;
#   color: #000000;
# }
# #T_ccb1d_row2_col3 {
#   background-color: #3b518b;
#   color: #f1f1f1;
# }
# #T_ccb1d_row3_col1, #T_ccb1d_row3_col2 {
#   background-color: #6ece58;
#   color: #000000;
# }
# #T_ccb1d_row3_col3 {
#   background-color: #2e6d8e;
#   color: #f1f1f1;
# }
# #T_ccb1d_row4_col1 {
#   background-color: #4ac16d;
#   color: #000000;
# }
# #T_ccb1d_row4_col2 {
#   background-color: #48c16e;
#   color: #f1f1f1;
# }
# #T_ccb1d_row4_col3 {
#   background-color: #25848e;
#   color: #f1f1f1;
# }
# #T_ccb1d_row5_col1 {
#   background-color: #2fb47c;
#   color: #f1f1f1;
# }
# #T_ccb1d_row5_col2 {
#   background-color: #2eb37c;
#   color: #f1f1f1;
# }
# #T_ccb1d_row5_col3, #T_ccb1d_row7_col1 {
#   background-color: #1f988b;
#   color: #f1f1f1;
# }
# #T_ccb1d_row6_col1 {
#   background-color: #21a685;
#   color: #f1f1f1;
# }
# #T_ccb1d_row6_col2 {
#   background-color: #21a585;
#   color: #f1f1f1;
# }
# #T_ccb1d_row6_col3 {
#   background-color: #25ab82;
#   color: #f1f1f1;
# }
# #T_ccb1d_row7_col2 {
#   background-color: #1f978b;
#   color: #f1f1f1;
# }
# #T_ccb1d_row7_col3 {
#   background-color: #3aba76;
#   color: #f1f1f1;
# }
# #T_ccb1d_row8_col1 {
#   background-color: #228b8d;
#   color: #f1f1f1;
# }
# #T_ccb1d_row8_col2 {
#   background-color: #238a8d;
#   color: #f1f1f1;
# }
# #T_ccb1d_row8_col3 {
#   background-color: #56c667;
#   color: #000000;
# }
# #T_ccb1d_row9_col1 {
#   background-color: #277f8e;
#   color: #f1f1f1;
# }
# #T_ccb1d_row9_col2 {
#   background-color: #277e8e;
#   color: #f1f1f1;
# }
# #T_ccb1d_row9_col3 {
#   background-color: #73d056;
#   color: #000000;
# }
# #T_ccb1d_row10_col1 {
#   background-color: #2c728e;
#   color: #f1f1f1;
# }
# #T_ccb1d_row10_col2 {
#   background-color: #2c718e;
#   color: #f1f1f1;
# }
# #T_ccb1d_row10_col3 {
#   background-color: #8ed645;
#   color: #000000;
# }
# #T_ccb1d_row11_col1 {
#   background-color: #31678e;
#   color: #f1f1f1;
# }
# #T_ccb1d_row11_col2 {
#   background-color: #31668e;
#   color: #f1f1f1;
# }
# #T_ccb1d_row11_col3 {
#   background-color: #a8db34;
#   color: #000000;
# }
# #T_ccb1d_row12_col1 {
#   background-color: #365c8d;
#   color: #f1f1f1;
# }
# #T_ccb1d_row12_col2 {
#   background-color: #375b8d;
#   color: #f1f1f1;
# }
# #T_ccb1d_row12_col3 {
#   background-color: #bddf26;
#   color: #000000;
# }
# #T_ccb1d_row13_col1 {
#   background-color: #3c508b;
#   color: #f1f1f1;
# }
# #T_ccb1d_row13_col2 {
#   background-color: #3c4f8a;
#   color: #f1f1f1;
# }
# #T_ccb1d_row13_col3 {
#   background-color: #d0e11c;
#   color: #000000;
# }
# #T_ccb1d_row14_col1 {
#   background-color: #404588;
#   color: #f1f1f1;
# }
# #T_ccb1d_row14_col2 {
#   background-color: #414487;
#   color: #f1f1f1;
# }
# #T_ccb1d_row14_col3 {
#   background-color: #dde318;
#   color: #000000;
# }
# #T_ccb1d_row15_col1 {
#   background-color: #443983;
#   color: #f1f1f1;
# }
# #T_ccb1d_row15_col2 {
#   background-color: #453882;
#   color: #f1f1f1;
# }
# #T_ccb1d_row15_col3 {
#   background-color: #eae51a;
#   color: #000000;
# }
# #T_ccb1d_row16_col1, #T_ccb1d_row16_col2 {
#   background-color: #472d7b;
#   color: #f1f1f1;
# }
# #T_ccb1d_row16_col3 {
#   background-color: #f1e51d;
#   color: #000000;
# }
# #T_ccb1d_row17_col1 {
#   background-color: #482374;
#   color: #f1f1f1;
# }
# #T_ccb1d_row17_col2 {
#   background-color: #482173;
#   color: #f1f1f1;
# }
# #T_ccb1d_row17_col3 {
#   background-color: #f8e621;
#   color: #000000;
# }
# #T_ccb1d_row18_col1, #T_ccb1d_row18_col2 {
#   background-color: #481769;
#   color: #f1f1f1;
# }
# #T_ccb1d_row18_col3 {
#   background-color: #fbe723;
#   color: #000000;
# }
# #T_ccb1d_row19_col1, #T_ccb1d_row19_col2 {
#   background-color: #460b5e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ccb1d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ccb1d_level0_col0" class="col_heading level0 col0" >t</th>
#       <th id="T_ccb1d_level0_col1" class="col_heading level0 col1" >true_soln</th>
#       <th id="T_ccb1d_level0_col2" class="col_heading level0 col2" >approx_soln</th>
#       <th id="T_ccb1d_level0_col3" class="col_heading level0 col3" >abs_diff</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ccb1d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ccb1d_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_ccb1d_row0_col1" class="data row0 col1" >5.000000</td>
#       <td id="T_ccb1d_row0_col2" class="data row0 col2" >5.000000</td>
#       <td id="T_ccb1d_row0_col3" class="data row0 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ccb1d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ccb1d_row1_col0" class="data row1 col0" >0.100000</td>
#       <td id="T_ccb1d_row1_col1" class="data row1 col1" >4.951229</td>
#       <td id="T_ccb1d_row1_col2" class="data row1 col2" >4.950000</td>
#       <td id="T_ccb1d_row1_col3" class="data row1 col3" >0.001229</td>
#     </tr>
#     <tr>
#       <th id="T_ccb1d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ccb1d_row2_col0" class="data row2 col0" >0.200000</td>
#       <td id="T_ccb1d_row2_col1" class="data row2 col1" >4.904837</td>
#       <td id="T_ccb1d_row2_col2" class="data row2 col2" >4.902500</td>
#       <td id="T_ccb1d_row2_col3" class="data row2 col3" >0.002337</td>
#     </tr>
#     <tr>
#       <th id="T_ccb1d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ccb1d_row3_col0" class="data row3 col0" >0.300000</td>
#       <td id="T_ccb1d_row3_col1" class="data row3 col1" >4.860708</td>
#       <td id="T_ccb1d_row3_col2" class="data row3 col2" >4.857375</td>
#       <td id="T_ccb1d_row3_col3" class="data row3 col3" >0.003333</td>
#     </tr>
#     <tr>
#       <th id="T_ccb1d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ccb1d_row4_col0" class="data row4 col0" >0.400000</td>
#       <td id="T_ccb1d_row4_col1" class="data row4 col1" >4.818731</td>
#       <td id="T_ccb1d_row4_col2" class="data row4 col2" >4.814506</td>
#       <td id="T_ccb1d_row4_col3" class="data row4 col3" >0.004225</td>
#     </tr>
#     <tr>
#       <th id="T_ccb1d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ccb1d_row5_col0" class="data row5 col0" >0.500000</td>
#       <td id="T_ccb1d_row5_col1" class="data row5 col1" >4.778801</td>
#       <td id="T_ccb1d_row5_col2" class="data row5 col2" >4.773781</td>
#       <td id="T_ccb1d_row5_col3" class="data row5 col3" >0.005020</td>
#     </tr>
#     <tr>
#       <th id="T_ccb1d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ccb1d_row6_col0" class="data row6 col0" >0.600000</td>
#       <td id="T_ccb1d_row6_col1" class="data row6 col1" >4.740818</td>
#       <td id="T_ccb1d_row6_col2" class="data row6 col2" >4.735092</td>
#       <td id="T_ccb1d_row6_col3" class="data row6 col3" >0.005726</td>
#     </tr>
#     <tr>
#       <th id="T_ccb1d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ccb1d_row7_col0" class="data row7 col0" >0.700000</td>
#       <td id="T_ccb1d_row7_col1" class="data row7 col1" >4.704688</td>
#       <td id="T_ccb1d_row7_col2" class="data row7 col2" >4.698337</td>
#       <td id="T_ccb1d_row7_col3" class="data row7 col3" >0.006351</td>
#     </tr>
#     <tr>
#       <th id="T_ccb1d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ccb1d_row8_col0" class="data row8 col0" >0.800000</td>
#       <td id="T_ccb1d_row8_col1" class="data row8 col1" >4.670320</td>
#       <td id="T_ccb1d_row8_col2" class="data row8 col2" >4.663420</td>
#       <td id="T_ccb1d_row8_col3" class="data row8 col3" >0.006900</td>
#     </tr>
#     <tr>
#       <th id="T_ccb1d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ccb1d_row9_col0" class="data row9 col0" >0.900000</td>
#       <td id="T_ccb1d_row9_col1" class="data row9 col1" >4.637628</td>
#       <td id="T_ccb1d_row9_col2" class="data row9 col2"

# %% [markdown]
# #### (i)
#
# **Plot the numerical solution (using one choice of time step) and the analytic solution.**

# %%
plt.figure(figsize=(10, 6))

h1 = 0.5
h2 = 0.1
h3 = 0.01
t1, y_h1 = forward_euler(u0=u0, t0=0, tend=2, h=h1, a=a, f=f)
t2, y_h2 = forward_euler(u0=u0, t0=0, tend=2, h=h2, a=a, f=f)
t3, y_h3 = forward_euler(u0=u0, t0=0, tend=2, h=h3, a=a, f=f)

plt.scatter(t1, y_h1, color='blue', label=f'Forward Euler Approximation (h={h1})')
plt.scatter(t2, y_h2, linewidths=2, color='green', label=f'Forward Euler Approximation (h={h2})')
plt.scatter(t3, y_h3, linewidths=2, color='red', label=f'Forward Euler Approximation (h={h3})')

# Plotting analytical solution
true_y = []
for i in t:
    true_y.append( u(u0=u0, a=a, f=f, t=i) )
plt.plot(t, true_y, linewidth=4, color='black', label='True Analytical Solution')

plt.xlabel('t')
plt.ylabel('u(t)')
plt.title(f'Comparison of forward Euler (step sizes = {h1}, {h2}, {h3}) and the analytical solution')
plt.legend()
plt.show()

# %% [markdown]
# #### (ii)
#
# **Compute the error in the numerical solution (compared with the analytic solution) at $t=2$ using different numerical integration time steps $\Delta t = 10^{-5}, 5 \times 10^{-5}, 10^{-4}, 5 \times 10^{-4}, 10^{-3}$ and $5 \times 10^{-3}$. Plot a curve, where the x-axis is the time step and the y-axis is the absolute error. Use log scale for both x and y axes and write down the slope.**

# %% [markdown]
# **What did we learn here? The forward Euler method can be used to find a numerical solution to an ODE, and the numerical solution converges toward the true solution with a first-order rate of convergence (i.e., the error decreases as $\approx \Delta t$, not $\approx \Delta t^2$ or something else).**

# %% [markdown]
# ## Question 2.

# %% [markdown]
# **Consider the model with a cubic nonlinearity:**
#
# $$\frac{du}{dt} = au + bu^2 - cu^3 + f$$
#
# **Let us fix two parameters $b = -4$ and $c = 4$. Then, depending on the choices of $a$ and $f$, the system will have distinct behavior. Numerically validate the solution behavior by using the forward Euler method and starting from different initial values:**

# %%
b = -4
c = 4

# %% [markdown]
# ### (a.)
#
# **When $a=4$ and $f=10$, the three roots of $au+bu^2-cu^3+f=0$ are $r_1 = 1.2868$ and $r_{2,3} = -1.1434 \pm 0.7971i$.**

# %%
a = 4
f = 10

r = np.array([ 1.2868, -1.1434 + 0.7971j, -1.1434 - 0.7971j ])

# %% [markdown]
# #### (i.)
#
# **Plot $au+bu^2-cu^3+f$ as a function of $u$ for the given values of parameters $a,b,c,f$.**

# %%
def du_dt(a, b, c, f, u):
   
    """
    ODE function u' = au + bu^2 - cu^3 + f.

    --- inputs ---
    - a: constant
    - f: constant
    - u: variable  
    """
    
    return (a*u + b*u**2 - c*u**3 + f)

xlim = [-4, 4]
ylim = [-300, 200]

u = np.linspace(xlim[0], xlim[1], 1000)
u_diff_output = []
for u_curr in u:
    u_diff_output.append(du_dt(a=a, b=b, c=c, f=f, u=u_curr))

plt.figure(figsize=(15, 10))
plt.plot([xlim[0], xlim[1]], [0,0], linestyle='-', color='black', label='x-axis')
plt.plot(u, u_diff_output, label=f'function: $au + bu^2 - cu^3 + f$')

plt.scatter(r[0].real, 0, color='black')
plt.plot([r[0].real, r[0].real], 
         [ylim[0], 0], 
         linestyle='dashed', 
         color='black', 
         label=f'x-intercept: ({r[0].real}, {0})')

plt.xlim(xlim[0], xlim[1])
plt.ylim(ylim[0], ylim[1])

plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# #### (ii.)
#
# **Select different values of the initial condition $u_0$, and plot the numerical solutions in order to illustrate different solution behavior for different $u_0$.**

# %%
def forward_euler(u0, t0, tend, h, a, b, c, f):
    
    """
    Implementing forward euler to estimate numerical solution of u'.

    --- inputs ---
    - u0: initial condition
    - t0: initial time
    - tend: final time
    - h: time-step
    - a: constant (for function du_dt)
    - f: constant (for function du_dt)
    """
    
    num_steps = int((tend-t0)/h)
    t = np.linspace(t0, tend, num_steps+1)
    y = np.zeros(num_steps+1)
    y[0] = u0
    
    for i in range(num_steps):
        y[i+1] = y[i] + h * du_dt(a=a, b=b, c=c, f=f, u=y[i])
    
    return t, y

# Defining plot parameters
plt.figure(figsize=(15, 10))
plt.xlabel('t')
plt.ylabel('u(t)')
plt.title('Comparison of forward Euler (for various initial conditions)')
plt.grid(False)

# Plotting forward euler approximation (for various step-sizes)
u01 = 0
u02 = 1
u03 = -1

t1, y_u01 = forward_euler(u0=u01, t0=xlim[0], tend=xlim[1], h=0.01, a=a, b=b, c=c, f=f)
t2, y_u02 = forward_euler(u0=u02, t0=xlim[0], tend=xlim[1], h=0.01, a=a, b=b, c=c, f=f)
t3, y_u03 = forward_euler(u0=u03, t0=xlim[0], tend=xlim[1], h=0.01, a=a, b=b, c=c, f=f)

plt.scatter(t1, y_u01, alpha=0.4, color='#008081', label=f'Forward Euler Approximation (u0={u01})')
plt.scatter(t2, y_u02, alpha=0.4, label=f'Forward Euler Approximation (u0={u02})')
plt.scatter(t3, y_u03, alpha=0.4, color='#7362FB', label=f'Forward Euler Approximation (u0={u03})')

plt.plot([xlim[0], xlim[1]], [r[0].real, r[0].real], linestyle='--', color='black', label=f'asymptotic line at y={r[0].real}')

plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### (b.)
#
# **When $a=4$ and $f=2$, the three roots of $au+bu^2-cu^3+f=0$ are
# $r_1 = -1.4516$, $r_2 = 0.8546$ and $r_3 = -0.4030$.**

# %%
a=4
f=2

r = np.array([ -1.4516, 0.8546, -0.4030 ])

# %% [markdown]
# #### (i.)
#
# **Plot $au+bu^2-cu^3+f$ as a function of $u$ for the given values of parameters $a,b,c,f$.**

# %%
plt.figure(figsize=(15, 10))

xlim = [-3, 3]
ylim = [-10, 10]

u = np.linspace(xlim[0], xlim[1], 1000)
u_diff_output = []
for u_curr in u:
    u_diff_output.append(du_dt(a=a, b=b, c=c, f=f, u=u_curr))

plt.plot([xlim[0], xlim[1]], [0,0], linestyle='-', color='black', label='x-axis')
plt.plot(u, u_diff_output, label=f'function: $au + bu^2 - cu^3 + f$')

plt.scatter(r[0].real, 0, color='black')
plt.plot([r[0].real, r[0].real], 
         [ylim[0], 0], 
         linestyle='dashed', 
         color='black', 
         label=f'x-intercept: ({r[0].real}, {0})')

plt.scatter(r[1].real, 0, color='black')
plt.plot([r[1].real, r[1].real], 
         [ylim[0], 0], 
         linestyle='dashed', 
         color='black', 
         label=f'x-intercept: ({r[1].real}, {0})')

plt.scatter(r[2].real, 0, color='black')
plt.plot([r[2].real, r[2].real], 
         [ylim[0], 0], 
         linestyle='dashed', 
         color='black', 
         label=f'x-intercept: ({r[2].real}, {0})')

plt.xlim(xlim[0], xlim[1])
plt.ylim(ylim[0], ylim[1])

plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# #### (ii.)
#
# **Select different values of the initial condition $u_0$, and plot the numerical solutions in order to illustrate different solution behavior for different $u_0$.**

# %%
# Defining plot parameters
plt.figure(figsize=(15, 10))
plt.xlabel('t')
plt.ylabel('u(t)')
plt.title('Comparison of forward Euler (for various initial conditions)')
plt.grid(False)

# Plotting forward euler approximation (for various step-sizes)
u01 = 0
u02 = -0.403
u03 = -1

t1, y_u01 = forward_euler(u0=u01, t0=xlim[0], tend=xlim[1], h=0.01, a=a, b=b, c=c, f=f)
t2, y_u02 = forward_euler(u0=u02, t0=xlim[0], tend=xlim[1], h=0.01, a=a, b=b, c=c, f=f)
t3, y_u03 = forward_euler(u0=u03, t0=xlim[0], tend=xlim[1], h=0.01, a=a, b=b, c=c, f=f)

plt.scatter(t1, y_u01, alpha=0.4, color='#008081', label=f'Forward Euler Approximation (u0={u01})')
plt.scatter(t2, y_u02, alpha=0.4, label=f'Forward Euler Approximation (u0={u02})')
plt.scatter(t3, y_u03, alpha=0.4, color='#7362FB', label=f'Forward Euler Approximation (u0={u03})')

plt.plot([xlim[0], xlim[1]], [r[0].real, r[0].real], linestyle='--', color='black', label=f'asymptotic line at y={r[0].real}')
plt.plot([xlim[0], xlim[1]], [r[1].real, r[1].real], linestyle='--', color='black', label=f'asymptotic line at y={r[1].real}')
plt.plot([xlim[0], xlim[1]], [r[2].real, r[2].real], linestyle='--', color='black', label=f'asymptotic line at y={r[2].real}')

#plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# **What did we learn here? Nonlinear ODEs can potentially have multiple equilibria, or only one or zero equilibria, depending on the nonlinearity and the parameter values. Furthermore, the equilibrium points can be either stable or unstable.**

# %% [markdown]
# ## Question 3.
#
# **Consider the 2-dimensional linear model:**
#
# $$ \frac{du_1}{dt} = -au_1 + \omega u_2 + f_1$$
# $$ \frac{du_2}{dt} = -\omega u_1 - a u_2 + f_2$$
#
# **Use the forward Euler method to numerically solve the equation and plot the trajectories of $(u_1, u_2)$ in the two-dimensional space. Discuss the difference in the following three situations: (a) $a = 0$, (b) $a = 1$, and (c) $a = −1$. You may fix other parameters $\omega = 1$ and $f_1 = f_2 = 0$.**

# %% [markdown]
# **What did we learn here? Phase portraits can be helpful for characterizing the different behaviors of dynamical systems.**

# %% [markdown]
# ## Question 4.
#
# **Consider a Gaussian random variable $\mathbf{x} = (x_1, x_2)^T$ with the mean $\mathbf{\mu}$ and the covariance matrix $\mathbf{\Sigma}$ being in the following form,**
# $$ \mathbf{\mu} = \begin{pmatrix} \mathbf{\mu_1}\\ \mathbf{\mu_2} \end{pmatrix}, \quad \mathbf{\Sigma} = \begin{pmatrix} \mathbf{\Sigma_{11}} & \mathbf{\Sigma_{12}}\\ \mathbf{\Sigma_{21}} & \mathbf{\Sigma_{22}} \end{pmatrix} $$
# **where $\mathbf{x}_1$ and $\mathbf{x}_2$ are multi-dimensional.**
#
# **Show that the conditional desntiy is then given by:**
# $$ p(\mathbf{x}_1 | \mathbf{x}_2) \sim \mathcal{N}(\bar{\mathbf{\mu}}, \bar{\mathbf{\Sigma}}) $$
# **where**
# $$ \bar{\mathbf{\mu}} = \mathbf{\mu}_1 + \mathbf{\Sigma_{12}}\mathbf{\Sigma_{22}^{-1}}(\mathbf{x_2} - \mathbf{\mu_2}) \quad \text{and} \quad \bar{\mathbf{\Sigma}} = \mathbf{\Sigma_{11}} - \mathbf{\Sigma_{12}}\mathbf{\Sigma_{22}^{-1}}\mathbf{\Sigma_{21}} $$

# %% [markdown]
# **What did we learn here? For a multivariate Gaussian random variable, the conditional distribution is also Gaussian. Moreover, an analytical formula can be derived for the conditional mean and conditional covariance.**
